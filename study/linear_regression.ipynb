# %%
import tensorflow as tf
# Out:
# c:\Users\roseh\Desktop\study\deep_learning\venv\lib\site-packages\tensorflow\python\framework\dtypes.py:526: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# c:\Users\roseh\Desktop\study\deep_learning\venv\lib\site-packages\tensorflow\python\framework\dtypes.py:527: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# c:\Users\roseh\Desktop\study\deep_learning\venv\lib\site-packages\tensorflow\python\framework\dtypes.py:528: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# ...

# %%
x_train = [1,2,3]
y_train = [1,2,3]

W = tf.Variable(tf.random_normal([1]), name='weight') #random_normal(shape)
b = tf.Variable(tf.random_normal([1]), name='bias') #rank=1
#it is not python variable
#it is tensorflow(trainalbe) variable

#H(x) = Wx + b
hypothesis = x_train*W + b

#cost function
cost = tf.reduce_mean(tf.square(hypothesis - y_train))

#minimize cost
optimizer = tf.train.GradientDescentOptimizer(learning_rate=0.01)
train = optimizer.minimize(cost)

# %%
sess = tf.Session()
sess.run(tf.global_variables_initializer()) #we have to run varialbe_initializer to use variable

for step in range(2001):
    sess.run(train) #run the graph
    if step%20==0:
        print(step, sess.run(cost), sess.run(W), sess.run(b))
# Out:
# 0 13.646584 [-0.07664038] [-1.434729]
# 20 0.20737575 [1.2013482] [-0.82737076]
# 40 0.07784892 [1.3087568] [-0.7370756]
# 60 0.06970181 [1.3053749] [-0.6975404]
# 80 0.06329525 [1.2920831] [-0.6642926]
# 100 0.05748573 [1.2784573] [-0.633029]
# 120 0.052209467 [1.2653804] [-0.6032749]
# 140 0.047417488 [1.2529094] [-0.57492286]
# 160 0.043065306 [1.2410235] [-0.54790354]
# 180 0.039112598 [1.2296964] [-0.5221539]
# 200 0.03552267 [1.2189014] [-0.4976146]
# 220 0.032262266 [1.2086139] [-0.4742285]
# 240 0.02930109 [1.1988097] [-0.45194143]
# 260 0.026611729 [1.1894665] [-0.43070182]
# 280 0.02416919 [1.1805623] [-0.41046047]
# 300 0.021950835 [1.1720765] [-0.3911703]
# 320 0.019936109 [1.1639895] [-0.37278673]
# 340 0.018106291 [1.1562827] [-0.3552671]
# 360 0.016444424 [1.1489378] [-0.33857083]
# 380 0.014935105 [1.1419384] [-0.32265934]
# 400 0.013564303 [1.1352679] [-0.3074956]
# 420 0.012319319 [1.1289108] [-0.29304442]
# 440 0.011188607 [1.1228526] [-0.2792724]
# ...

# %%
# x_train = [1,2,3]
# y_train = [1,2,3]

#we can use place of data
X = tf.placeholder(tf.float32)
Y = tf.placeholder(tf.float32)


W = tf.Variable(tf.random_normal([1]), name='weight') #random_normal(shape)
b = tf.Variable(tf.random_normal([1]), name='bias') #rank=1

hypothesis = x_train*W + b

#cost function
cost = tf.reduce_mean(tf.square(hypothesis - y_train))

#minimize cost
optimizer = tf.train.GradientDescentOptimizer(learning_rate=0.01)
train = optimizer.minimize(cost)

sess = tf.Session()
sess.run(tf.global_variables_initializer())

for step in range(2001):
    #you can run like this
    cost_val, W_val, b_val, _ = sess.run([cost,W,b,train], feed_dict={X:[1,2,3], Y:[1,2,3]})
    if step%20==0:
        print(step, cost_val, W_val, b_val)
# Out:
# 0 37.68381 [-1.278923] [-0.5732876]
# 20 0.3584307 [0.64730227] [0.2538907]
# 40 0.018473662 [0.8370935] [0.31815675]
# 60 0.013994053 [0.8612429] [0.31046]
# 80 0.01268438 [0.86933446] [0.2965604]
# 100 0.011519942 [0.8756248] [0.28268898]
# 120 0.010462586 [0.88148427] [0.26940992]
# 140 0.009502282 [0.8870554] [0.25674918]
# 160 0.008630124 [0.89236355] [0.24468294]
# 180 0.007838019 [0.897422] [0.23318373]
# 200 0.007118626 [0.90224284] [0.22222497]
# 220 0.0064652488 [0.90683705] [0.21178122]
# 240 0.005871836 [0.91121536] [0.2018283]
# 260 0.0053328946 [0.9153879] [0.19234312]
# 280 0.00484343 [0.9193644] [0.18330371]
# 300 0.004398882 [0.92315394] [0.17468911]
# 320 0.0039951284 [0.92676544] [0.16647936]
# 340 0.0036284358 [0.9302072] [0.15865546]
# 360 0.0032954074 [0.9334872] [0.15119927]
# 380 0.0029929427 [0.936613] [0.14409345]
# 400 0.002718236 [0.9395921] [0.13732155]
# 420 0.0024687431 [0.94243103] [0.1308679]
# 440 0.0022421563 [0.94513655] [0.12471754]
# ...

# %%
import matplotlib.pyplot as plt

X = [1,2,3]
Y = [1,2,3]

W = tf.placeholder(tf.float32)
hypothesis = W * X

cost = tf.reduce_mean(tf.square(hypothesis-Y))

sess = tf.Session()
sess.run(tf.global_variables_initializer())

W_val = []
cost_val = []

for i in range(-30,50):
    feed_W = i*0.1
    curr_cost, curr_W = sess.run([cost, W], feed_dict={W:feed_W})
    W_val.append(curr_W)
    cost_val.append(curr_cost)

learning_rate = 0.1
gradient = tf.reduce_mean((W*X-Y)*X)
descent = W - learning_rate * gradient
update = W.assign(descent)
# its same with this
# optimizer = tf.train.GradientDescentOptimizer(learning_rate=0.01)
# train = optimizer.minimize(cost)

plt.plot(W_val, cost_val)
plt.show()

# %%
X = [1,2,3]
Y = [1,2,3]

W = tf.Variable(-3.0)
hypothesis = W * X

cost = tf.reduce_mean(tf.square(hypothesis-Y))
optimizer = tf.train.GradientDescentOptimizer(learning_rate=0.1)
train = optimizer.minimize(cost)

sess = tf.Session()
sess.run(tf.global_variables_initializer())

for step in range(100):
    print(step, sess.run(W))
    sess.run(train)
# Out:
# 0 -3.0
# 1 0.7333336
# 2 0.98222226
# 3 0.9988148
# 4 0.99992096
# 5 0.9999947
# 6 0.99999964
# 7 0.99999994
# 8 1.0
# 9 1.0
# 10 1.0
# 11 1.0
# 12 1.0
# 13 1.0
# 14 1.0
# 15 1.0
# 16 1.0
# 17 1.0
# 18 1.0
# 19 1.0
# 20 1.0
# 21 1.0
# 22 1.0
# 23 1.0
# 24 1.0
# 25 1.0
# 26 1.0
# 27 1.0
# 28 1.0
# 29 1.0
# 30 1.0
# 31 1.0
# 32 1.0
# 33 1.0
# 34 1.0
# 35 1.0
# 36 1.0
# 37 1.0
# 38 1.0
# 39 1.0
# 40 1.0
# 41 1.0
# 42 1.0
# 43 1.0
# 44 1.0
# 45 1.0
# 46 1.0
# 47 1.0
# 48 1.0
# 49 1.0
# 50 1.0
# 51 1.0
# 52 1.0
# 53 1.0
# 54 1.0
# 55 1.0
# 56 1.0
# 57 1.0
# 58 1.0
# 59 1.0
# 60 1.0
# 61 1.0
# 62 1.0
# 63 1.0
# 64 1.0
# 65 1.0
# 66 1.0
# 67 1.0
# 68 1.0
# 69 1.0
# 70 1.0
# 71 1.0
# 72 1.0
# 73 1.0
# 74 1.0
# 75 1.0
# 76 1.0
# 77 1.0
# 78 1.0
# 79 1.0
# 80 1.0
# 81 1.0
# 82 1.0
# 83 1.0
# 84 1.0
# 85 1.0
# 86 1.0
# 87 1.0
# 88 1.0
# 89 1.0
# 90 1.0
# 91 1.0
# 92 1.0
# 93 1.0
# 94 1.0
# 95 1.0
# 96 1.0
# 97 1.0
# 98 1.0
# 99 1.0

# %%
X = [1,2,3]
Y = [1,2,3]

W = tf.Variable(5.)
hypothesis = W * X

gradient = tf.reduce_mean((X*W-Y)*W)*2
cost = tf.reduce_mean(tf.square(hypothesis-Y))
optimizer = tf.train.GradientDescentOptimizer(learning_rate=0.01)

gvs = optimizer.compute_gradients(cost)
#you can change the value of gradient
apply_gradients = optimizer.apply_gradients(gvs)

sess = tf.Session()
sess.run(tf.global_variables_initializer())

for step in range(100):
    print(step, sess.run([gradient, W, gvs])) #same gradient
    sess.run(apply_gradients)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_8452\4089853061.py in <module>
#      19
#      20 for step in range(100):
# ---> 21     gradient_val, gvs_val, _ = sess.run([gradient, gvs, apply_gradients])
#      22     print(step, gradient_val, gvs_val)
#
# c:\Users\roseh\Desktop\study\deep_learning\venv\lib\site-packages\tensorflow\python\client\session.py in run(self, fetches, feed_dict, options, run_metadata)
#     927     try:
#     928       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 929                          run_metadata_ptr)
#     930       if run_metadata:
#     931         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# c:\Users\roseh\Desktop\study\deep_learning\venv\lib\site-packages\tensorflow\python\client\session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
# ...
